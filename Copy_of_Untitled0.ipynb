# %% [markdown]
# <a href="https://colab.research.google.com/github/amanyadav397190-del/Data-Cleaning/blob/main/Copy_of_Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Pehle cell mein ye code likhein aur run karein
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# SQLite database se connect karne ke liye
# %sql sqlite://
# %config SqlMagic.autopandas = True

# %% [markdown]
# QUE 1:- Q1. Create a New Database and  Table for Employees
# Task: Create a new database named
# company_db
# and Create a table named
# employees
# columns:

# %%
# %%sql
# CREATE TABLE employees (
#     employee_id INT PRIMARY KEY,
#     first_name VARCHAR(50),
#     last_name VARCHAR(50),
#     department VARCHAR(50),
#     salary INT,
#     hire_date DATE
# );
# Out:
#  * sqlite://
# Done.
# []

# %% [markdown]
# **Q2.** Insert Data into Employees Table
# Task:  Insert the following sample records into the
# employee_id
# 101
# 102
# 103
# 104
# 105
# first_name
# Amit
# Riya
# Raj
# last_name
# with the following
# employees
# table.
#
#
#
# ```
# # This is formatted as code
# ```

# %%
# %%sql
# INSERT INTO employees VALUES (101, 'Amit', 'Sharma', 'HR', 50000, '2020-01-15');
# INSERT INTO employees VALUES (102, 'Riya', 'Kapoor', 'Sales', 75000, '2019-03-22');
# INSERT INTO employees VALUES (103, 'Raj', 'Mehta', 'IT', 90000, '2018-07-11');
# INSERT INTO employees VALUES (104, 'Neha', 'Verma', 'IT', 85000, '2021-09-01');
# INSERT INTO employees VALUES (105, 'Arjun', 'Singh', 'Finance', 60000, '2022-02-10');
# Out:
#  * sqlite://
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# []

# %% [markdown]
# Q3. Display All Employee Records Sorted by Salary (Lowest to Highest)
# Hint: Use the
# ORDER BY
# clause on the salary column.

# %%
# %%sql
# SELECT * FROM employees
# ORDER BY salary ASC;

# %% [markdown]
# Q4. Show Employees Sorted by Department (A–Z) and Salary (High → Low)

# %%
# %%sql
# SELECT * FROM employees
# ORDER BY department ASC, salary DESC;

# %% [markdown]
# Q5. List All Employees in the IT Department, Ordered by Hire Date (Newest First)

# %%
# %%sql
# SELECT * FROM employees
# WHERE department = 'IT'
# ORDER BY hire_date DESC;

# %% [markdown]
# Q6. Create and Populate a Sales Table
# Task: Create a table
# sales
# sale_id
# to track sales data

# %%
# %%sql
# CREATE TABLE sales (
#     sale_id INT,
#     amount INT,
#     customer_name VARCHAR(50),
#     sale_date DATE
# );
#
# INSERT INTO sales VALUES (1, 1500, 'Aditi', '2024-08-01');
# INSERT INTO sales VALUES (2, 2200, 'Rohan', '2024-08-03');
# INSERT INTO sales VALUES (3, 3500, 'Aditi', '2024-09-05');
# INSERT INTO sales VALUES (4, 2700, 'Meena', '2024-09-15');
# INSERT INTO sales VALUES (5, 4500, 'Rohan', '2024-09-25');
# Out:
#  * sqlite://
# Done.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# []

# %% [markdown]
# Q7. Display All Sales Records Sorted by Amount (Highest → Lowest)
# Hint: Use
# ORDER BY amount DESC

# %%
# %%sql
# SELECT * FROM sales
# ORDER BY amount DESC;

# %% [markdown]
# Q8. Show All Sales Made by Customer “Aditi”

# %%
# %%sql
# SELECT * FROM sales
# WHERE customer_name = 'Aditi';

# %% [markdown]
# Q9. What is the Difference Between a Primary Key and a Foreign Key?

# %% [markdown]
# # ANS
# Primary Key: Ye ek unique identifier hota hai jo table ke har record ko pehchaanta hai. Isme Duplicate ya NULL values allow nahi hoti.
#
#
# Foreign Key: Ye ek column hota hai jo doosri table ki Primary Key se link hota hai, taaki do tables ke beech relation ban sake

# %% [markdown]
# # Q10. What Are Constraints in SQL and Why Are They Used?
#
#
# ## ANS
# Constraints: SQL mein constraints wo rules hote hain jo table ke columns par apply kiye jaate hain (jaise NOT NULL, UNIQUE, PRIMARY KEY).
#
#
# Why used: Inka use data ki accuracy aur reliability ko maintain karne ke liye kiya jata hai taaki galat data database mein enter na ho
